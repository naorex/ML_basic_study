# %%
#必要なライブラリのインポートを行う TF-IDFを用いたテキストの特徴量化を用いて教師あり学習を実行する
import seaborn as sns
import pandas as pd
import os as os
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split

# %%
# ディレクトリを作成
DIR = "naive_baize/"
# DIRの名称のディレクトリがなければ作成
if not os.path.exists(DIR):
    os.makedirs(DIR)

# %%
#csvデータの読み込み
df = pd.read_csv("./naive_baize/review.csv")
df
# Out:
#     好きなスポーツの一つが水泳です。水泳は、自分が泳ぐのも好きですが観るのも大好きです。好きな理由は、スピーディーな展開で前半から後半にかけて各選手がデットヒートを繰り広げる展開がとても面白いからです。残り数メートルでの逆転など、最後まで気を抜く事が出来ない展開が面白いところです。選手の日頃の練習の成果が思いっきり出る競技のため、選手がどれだけ努力したか良く分かるところが魅力でもあります。そんな、水泳で好きな選手は入江選手です。背泳ぎのオリンピック銀メダリストで現在でも、活躍されており東京オリンピックでもメダルが期待できます。  \
# 0    好きなスポーツは野球です。なぜ好きなのかですが、元々高校野球が大好きで甲子園はセンバツや夏の...
# 1    競泳が好きです。短時間で決着がつきますが、タイムで競うので勝敗が公平だからです。また自分も水...
# 2    好きなスポーツは硬式テニスです。好きな理由として、緩急つけたメリハリのある連続したラリーです...
# 3    私が好きなスポーツはずばり「スティールチャレンジ」です。私が「スティールチャレンジ」を好きな...
# 4    私が好きなスポーツは卓球です。自分が学生時代に卓球をやっていたこともあり、いつのまにか好きに...
# ..                                                 ...
# 294  私が野球を好きなのは、プレー一つ一つに煌めきを感じるから。\r\n特に感じるのは高校野球（春...
# 295  ほかのスポーツに比べて、ゆっくりと鑑賞できるところです。いい意味で展開が遅いというか、ポップ...
# 296  私は実家が球場の隣駅にある事もあり、野球がすごく身近なスポーツでした。親の影響もあり、よく球...
# 297  野球は少年野球から高校野球、プロ野球と日本人には非常に馴染み深いスポーツです。サッカーに比べ...
# 298  学生時代は小学生、中学生と自分でも野球をやっていて昔から好きなスポーツであった。一見するとボ...
#
#              水泳
# 0            野球
# 1            競泳
# 2           テニス
# 3    スティールチャレンジ
# 4            卓球
# ..          ...
# 294          野球
# 295          野球
# 296          野球
# 297          野球
# 298          野球
#
# [299 rows x 2 columns]

# %%
#元データにカラム名が無いため、カラム名を追加します
df.columns = ["text", "sports"]
df
# Out:
#                                                   text      sports
# 0    好きなスポーツは野球です。なぜ好きなのかですが、元々高校野球が大好きで甲子園はセンバツや夏の...          野球
# 1    競泳が好きです。短時間で決着がつきますが、タイムで競うので勝敗が公平だからです。また自分も水...          競泳
# 2    好きなスポーツは硬式テニスです。好きな理由として、緩急つけたメリハリのある連続したラリーです...         テニス
# 3    私が好きなスポーツはずばり「スティールチャレンジ」です。私が「スティールチャレンジ」を好きな...  スティールチャレンジ
# 4    私が好きなスポーツは卓球です。自分が学生時代に卓球をやっていたこともあり、いつのまにか好きに...          卓球
# ..                                                 ...         ...
# 294  私が野球を好きなのは、プレー一つ一つに煌めきを感じるから。\r\n特に感じるのは高校野球（春...          野球
# 295  ほかのスポーツに比べて、ゆっくりと鑑賞できるところです。いい意味で展開が遅いというか、ポップ...          野球
# 296  私は実家が球場の隣駅にある事もあり、野球がすごく身近なスポーツでした。親の影響もあり、よく球...          野球
# 297  野球は少年野球から高校野球、プロ野球と日本人には非常に馴染み深いスポーツです。サッカーに比べ...          野球
# 298  学生時代は小学生、中学生と自分でも野球をやっていて昔から好きなスポーツであった。一見するとボ...          野球
#
# [299 rows x 2 columns]

# %%
#上記データフレームをトレーニングデータセットとテストデータセットに分割
X = df["text"]
Y = df["sports"]
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, train_size=0.7, test_size=0.3, random_state=None)

# %%
#文字データのベクトル化(数値化)
model = make_pipeline(TfidfVectorizer(), MultinomialNB())

# %%
#学習の実行
model.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer()),
#                 ('multinomialnb', MultinomialNB())])

# %%
#評価
print('Train accuracy = %.3f' % model.score(X_train, Y_train))
print('Test accuracy = %.3f' % model.score(X_test, Y_test))
# Out:
# Train accuracy = 0.794
# Test accuracy = 0.444
